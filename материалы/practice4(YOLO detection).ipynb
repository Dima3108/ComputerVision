# %% [markdown]
# ## Детекция
#
# ### Постановка задачи
#
# Даны классы объектов, которые мы хотим детектировать:
# - кошка;
# - собака;
# - человек;
# - ...
#
# На вход нейросети подается RGB картинка (так же, как и в задаче классификации). На выходе нейросеть выдает набор пар (класс, координаты bounding box).
# - (собака, [35, 12], [64, 56]);
# - (кошка, [16, 45], [33, 54]);
# - ...
#
# Координата каждого bounding box — это пара [x1, y1], [x2, y2], где [x1, y1] — координаты левого верхнего угла bounding box'а, [x2, y2] — координаты правого нижнего угла bounding box'а.
#
# ![image.png](attachment:image.png)
#
# Иногда координаты bounding box'ов кодируют по-другому: парой [x1, y1], [w, h], где [x1, y1] — координаты левого верхнего угла bounding box'а, [w, h] — ширина и длина bounding box'а:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Пример дообучения модели YOLO для решения задачи детекции
#
# ### Разметка данных
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Альтернативы: Label Studio, cvat
#
# ### Структура папок
#
# ![image-3.png](attachment:image-3.png)
#
#
# ### Формат Ultralytics YOLO
#
# Формат Ultralytics YOLO — это формат конфигурации набора данных, который позволяет определить корневой каталог набора данных, относительные пути к каталогам изображений для обучения/проверки/тестирования или *.txt файлы, содержащие пути к изображениям, и словарь названий классов
#
# ![image-4.png](attachment:image-4.png)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8m.pt')  # load a pretrained model 

# Train the model
results = model.train(data='C:\\Users\\Dmitry\\Desktop\\dataset2\\data.yaml',
                       epochs=200, 
                       imgsz=640,
                       name='pollen_yolov8m_640', 
                       model='yolov8m.pt',
                       project='runs/train2')

# %% [markdown]
# ### После обучения
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Дополнительно
#
#
# https://deepmachinelearning.ru/docs/Neural-networks/Object-detection
#
# https://youtu.be/6WXUNNYysww
#
# https://learnopencv.com/selective-search-for-object-detection-cpp-python/
#
# https://towardsdatascience.com/what-is-transposed-convolutional-layer-40e5e6e31c11
#
# https://docs.ultralytics.com/ru/datasets/detect/
#
# https://habr.com/ru/articles/714232/

# %% [markdown]
# ### Задача 6
# 1. Выбрать датасет изображений для обучения  модели для детекции
# 2. Реализовать модель CNN и обучить ее на вашем датасете.
# 4. Подготовить отчет с примерами применения вашей модели для детекции. К отчету приложить обученную модель
#
# * Ресурс с датасетами для обучения https://www.kaggle.com/metavision/datasets
